# %% [markdown]
# <a href="https://colab.research.google.com/github/saikrishnaa1773/Innomatics/blob/main/Innomatics_Task7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 1: Smart Light Controller

# %%
class SmartLight:

    def __init__(self, light_name, status):
        self.light_name = light_name
        self.status = status

    def display_status(self):
        print(self.light_name + " is " + self.status)


light = SmartLight("Bedroom Light", "ON")
light.display_status()
# Out:
# Bedroom Light is ON

# %% [markdown]
# Problem 2: Employee ID Card System

# %%
class Employee:

    def __init__(self, name, emp_id, department):
        self.name = name
        self.emp_id = emp_id
        self.department = department

    def display_id_card(self):
        print("Employee ID Card")
        print("Name:", self.name)
        print("ID:", self.emp_id)
        print("Department:", self.department)


emp = Employee("Rahul", "EMP102", "IT")
emp.display_id_card()
# Out:
# Employee ID Card
# Name: Rahul
# ID: EMP102
# Department: IT

# %% [markdown]
# Problem 3: Mobile Contact Record

# %%
class Contact:

    def __init__(self, name, phone):
        self.name = name
        self.phone = phone

    def display_contact(self):
        print("Contact Saved")
        print("Name:", self.name)
        print("Phone:", self.phone)


contact = Contact("Anita", "9876543210")
contact.display_contact()
# Out:
# Contact Saved
# Name: Anita
# Phone: 9876543210

# %% [markdown]
# Problem 4: Product Price Tag Generator

# %%
class Product:

    def __init__(self, product_name, price):
        self.product_name = product_name
        self.price = price

    def display_price_tag(self):
        print("Product:", self.product_name)
        print("Price: ₹" + str(self.price))


product = Product("Headphones", 2499)
product.display_price_tag()
# Out:
# Product: Headphones
# Price: ₹2499

# %% [markdown]
# Problem 5: Movie Rating Display System

# %%
class Movie:

    def __init__(self, movie_name, rating):
        self.movie_name = movie_name
        self.rating = rating

    def display_movie(self):
        print("Movie:", self.movie_name)
        print("Rating:", self.rating, "/ 5")


movie = Movie("Inception", 4.8)
movie.display_movie()
# Out:
# Movie: Inception
# Rating: 4.8 / 5

# %% [markdown]
# Problem 6: Delivery Address Manager

# %%
class Delivery:

    def __init__(self, customer_name, address):
        self.customer_name = customer_name
        self.address = address

    def display_delivery_details(self):
        print("Delivery Details")
        print("Customer:", self.customer_name)
        print("Address:", self.address)


delivery = Delivery("Suman", "Hyderabad")
delivery.display_delivery_details()
# Out:
# Delivery Details
# Customer: Suman
# Address: Hyderabad
