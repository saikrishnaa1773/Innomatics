# %% [markdown]
# <a href="https://colab.research.google.com/github/saikrishnaa1773/Innomatics/blob/main/Innomatics_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. User Login Check

# %%
username="admin"
password="1234"

input_username=input("Enter username: ")
input_password=input("Enter password: ")

if input_username==username and input_password==password:
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter username: deekshita
# Enter password: 1234
# Invalid Credentials

# %% [markdown]
# 2. Pass / Fail Analyzer

# %%
marks = list(map(int,input().split(",")))

pass_count=0
fail_count=0

for i in marks:
  if i>=50:
    pass_count+=1
  else:
    fail_count+=1

print("-------Final Result-------")
print("Total Students:",len(marks))
print("Pass students: ",pass_count)
print("Fail students: ",fail_count)
# Out:
# 2
# -------Final Result-------
# Total Students: 1
# Pass students:  0
# Fail students:  1

# %% [markdown]
# 3. Simple Data Cleaner

# %%
names=list(map(str,input().split(",")))
cleaned_names=[]
for name in names:
  cleaned=name.strip()                                # remove outer spaces
  cleaned=cleaned.replace('"','').replace("'","")     # remove double and single quotes
  cleaned=cleaned.strip()                             # remove spaces again
  cleaned=cleaned.lower()                             # convert to lowercase
  cleaned_names.append(cleaned)

print("["+",".join(f'"{name}"' for name in cleaned_names)+"]")
# Out:
# john, mary ,alex
# ["john","mary","alex"]

# %% [markdown]
# 4. Message Length Analyzer

# %%
msgs=list(map(str,input().split(",")))

for msg in msgs:
  length=len(msg)
  print("Message:",msg)
  print("Length:",length)

  if length>10:
    print("This message is longer than 10 characters")

  print()
# Out:
# hi hello this is deekshita
# Message: hi hello this is deekshita
# Length: 26
# This message is longer than 10 characters

# %% [markdown]
# 5. Error Message Detector

# %%
logs=list(map(str,input().split(",")))

count=0

for log in logs:
  cleaned=log.strip()               # remove spaces
  cleaned=cleaned.replace('"','')   # remove quotes
  cleaned=cleaned.replace("'","")   # remove single quotes

  if cleaned=="ERROR":
    count+=1

print("Total Errors:",count)
# Out:
# info error debug error
# Total Errors: 0
