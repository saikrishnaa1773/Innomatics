# %% [markdown]
# <a href="https://colab.research.google.com/github/saikrishnaa1773/Innomatics/blob/main/Innomatics_task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 1: Unique Words in a Sentence

# %%
sentence = input("Enter sentence: ")

#  Split sentence into words
words = sentence.split()

# set (removes duplicates)
unique_words = set(words)


print("Unique words count:", len(unique_words))
print("Unique words:", unique_words)
# Out:
# Enter sentence: hi hello everyone
# Unique words count: 3
# Unique words: {'hi', 'hello', 'everyone'}

# %% [markdown]
# Problem 2: Highest Salary from Employee Data

# %%
employees = {
    "Ravi": 75000,
    "Anita": 68000,
    "Kiran": 72000
}

#  Find maximum salary
highest_salary = max(employees.values())


for name, salary in employees.items():
    if salary == highest_salary:
        print("Highest Salary:", name, "-", salary)
# Out:
# Highest Salary: Ravi - 75000

# %% [markdown]
# Problem 3: Find Maximum and Minimum Values

# %%
numbers = [45, 22, 89, 10, 66]

# first number as max and min
maximum = numbers[0]
minimum = numbers[0]


for num in numbers:
    if num > maximum:
        maximum = num
    if num < minimum:
        minimum = num

print("List:", numbers)
print("Max:", maximum)
print("Min:", minimum)
# Out:
# List: [45, 22, 89, 10, 66]
# Max: 89
# Min: 10

# %% [markdown]
# Problem 4: Count Products Above Price 1000

# %%
prices = [450, 1200, 899, 1500, 300]

count = 0

for price in prices:
    if price > 1000:
        count += 1

print("Products above 1000:", count)
# Out:
# Products above 1000: 2

# %% [markdown]
# Problem 5: Calculate Attendance Percentage

# %%
attendance = ["P", "P", "A", "P", "P"]

total_days = len(attendance)
present_days = attendance.count("P")

percentage = (present_days / total_days) * 100

print("Attendance Percentage:", percentage)
# Out:
# Attendance Percentage: 80.0

# %% [markdown]
# Problem 6: Remove Duplicate Phone Numbers

# %%
phone_numbers = [9876543210, 9123456789, 9876543210]

unique_numbers = set(phone_numbers)

print("Unique phone numbers:", unique_numbers)
# Out:
# Unique phone numbers: {9876543210, 9123456789}

# %% [markdown]
# Problem 7: Count Character Frequency

# %%
text = "python"

char_count = {}

for char in text:
    if char in char_count:
        char_count[char] += 1
    else:
        char_count[char] = 1

print(char_count)
# Out:
# {'p': 1, 'y': 1, 't': 1, 'h': 1, 'o': 1, 'n': 1}

# %% [markdown]
# Problem 8: Convert List to Tuple

# %%
numbers = [10, 20, 30]

result = tuple(numbers)

print("Tuple:", result)
# Out:
# Tuple: (10, 20, 30)

# %% [markdown]
# Problem 9: Check if Key Exists in Dictionary

# %%
employees = {"Ravi": 75000, "Anita": 68000}

if "Ravi" in employees:
    print("Employee exists")
else:
    print("Employee does not exist")
# Out:
# Employee exists

# %% [markdown]
# Problem 10: Calculate Average Marks

# %%
marks = [70, 75, 80, 65]

total = sum(marks)
count = len(marks)

average = total / count

print("Average Marks:", average)
# Out:
# Average Marks: 72.5
