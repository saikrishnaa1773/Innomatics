# %% [markdown]
# <a href="https://colab.research.google.com/github/saikrishnaa1773/Innomatics/blob/main/Innomatics_Task_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Problem 1: Mobile Recharge Validation System**

# %%
# List of valid recharge plans
VALID_PLANS = [199, 299, 399, 599]

# Function to validate recharge amount
def validate_recharge(amount):
    if amount < 50:
        print("❌ Recharge amount must be at least ₹50.")
        return False

    if amount not in VALID_PLANS:
        print("❌ Invalid plan selected.")
        print("Available plans are:", VALID_PLANS)
        return False

    return True


# Main program using while loop for retry
while True:
    try:
        recharge_amount = int(input("Enter recharge amount: ₹"))

        if validate_recharge(recharge_amount):
            print("✅ Recharge successful!")
            break   # Exit loop if valid

        else:
            print("Please try again.\n")

    except ValueError:
        print("❌ Please enter a valid number.\n")
# Out:
# Enter recharge amount: ₹60
# ❌ Invalid plan selected.
# Available plans are: [199, 299, 399, 599]
# Please try again.
#
# Enter recharge amount: ₹50
# ❌ Invalid plan selected.
# Available plans are: [199, 299, 399, 599]
# Please try again.
#
# Enter recharge amount: ₹399
# ✅ Recharge successful!

# %% [markdown]
# **Problem 2: Inventory Reorder Alert System**

# %%
# Function to check inventory status
def check_inventory(products):
    for product, quantity in products.items():
        if quantity < 15:
            print(f"⚠️ Reorder Alert: {product} has only {quantity} items left.")
        else:
            print(f"✅ Stock OK: {product} has {quantity} items available.")


# Sample inventory dictionary
inventory = {
    "Rice": 20,
    "Oil": 10,
    "Sugar": 5,
    "Flour": 18,
    "Salt": 25
}

# Calling the function
check_inventory(inventory)
# Out:
# ✅ Stock OK: Rice has 20 items available.
# ⚠️ Reorder Alert: Oil has only 10 items left.
# ⚠️ Reorder Alert: Sugar has only 5 items left.
# ✅ Stock OK: Flour has 18 items available.
# ✅ Stock OK: Salt has 25 items available.

# %% [markdown]
#  **Problem 3: Student Result Processing System**

# %%
# Function to process student result
def process_result(marks):
    total = 0

    # Loop to calculate total marks
    for mark in marks:
        total += mark

    # Calculate average
    average = total / len(marks)

    print(f"Average Marks: {average:.2f}")

    # Return result
    if average >= 50:
        return "Pass"
    else:
        return "Fail"


# Example list of student marks
student_marks = [60, 45, 70, 55, 80]

# Calling the function
result = process_result(student_marks)

print("Result:", result)
# Out:
# Average Marks: 62.00
# Result: Pass

# %% [markdown]
# **Problem 4: Cab Fare Estimator with Retry Option**

# %%
# Constants
BASE_FARE = 50
PER_KM_RATE = 12

# Function to calculate fare
def calculate_fare(distance, is_peak):
    fare = BASE_FARE + (distance * PER_KM_RATE)

    if is_peak:
        fare *= 1.25   # Adding 25% extra

    return fare


# Main program with retry option
while True:
    try:
        distance = float(input("Enter distance in km: "))

        peak_input = input("Is it peak hour? (yes/no): ").lower()
        is_peak = True if peak_input == "yes" else False

        total_fare = calculate_fare(distance, is_peak)

        print(f"🚖 Total Fare: ₹{total_fare:.2f}")

        retry = input("Do you want to calculate again? (yes/no): ").lower()
        if retry != "yes":
            print("Thank you for using Cab Fare Estimator!")
            break

    except ValueError:
        print("❌ Please enter valid numeric input.\n")
# Out:
# Enter distance in km: 30
# Is it peak hour? (yes/no): y
# 🚖 Total Fare: ₹410.00
# Do you want to calculate again? (yes/no): y
# Thank you for using Cab Fare Estimator!

# %% [markdown]
# **Problem 5: Employee Attendance Eligibility Checker**

# %%
# Function to check attendance eligibility
def check_eligibility(attendance):
    present_count = 0

    # Loop to count present days
    for day in attendance:
        if day == "P":
            present_count += 1

    total_days = len(attendance)

    # Avoid division by zero
    if total_days == 0:
        return "No attendance data available"

    attendance_percentage = (present_count / total_days) * 100

    print(f"Attendance Percentage: {attendance_percentage:.2f}%")

    # Return eligibility status
    if attendance_percentage >= 75:
        return "Eligible"
    else:
        return "Not Eligible"


# Example attendance list
attendance_record = ["P", "P", "A", "P", "P", "A", "P", "P"]

# Calling function
result = check_eligibility(attendance_record)

print("Status:", result)
# Out:
# Attendance Percentage: 75.00%
# Status: Eligible

# %% [markdown]
# **Problem 6: Password Strength Checker**

# %%
# Function to check password strength
def check_password_strength(password):

    # Rule 1: Minimum length
    if len(password) < 8:
        return "Weak Password (Minimum 8 characters required)"

    has_digit = False
    has_special = False

    # Loop over string
    for char in password:
        if char.isdigit():
            has_digit = True
        if char in "@#$":
            has_special = True

    # Check all conditions
    if has_digit and has_special:
        return "Strong Password ✅"
    else:
        return "Weak Password (Must contain at least one digit and one special character @#$)"


# Example usage
password_input = input("Enter password: ")
result = check_password_strength(password_input)
print(result)
# Out:
# Enter password: 1234
# Weak Password (Minimum 8 characters required)
